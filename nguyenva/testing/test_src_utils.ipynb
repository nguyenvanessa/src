# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '../../utils/')
import src_utils
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Read in master spreadsheet

# %%
df = pd.read_csv('../../utils/point_muts.csv', index_col=0, header=[0,1])

# %% [markdown]
# # 2. Test functions

# %%
src_utils.create_variant_index?
# Out:
# Signature: src_utils.create_variant_index(df)
# Docstring:
# Create variant index from DataFrame with index in hgvs format.
#
# Args:
#     df: DataFrame with index in hgvs format
# Returns:
#     variant_index: variant in [1 letter WTAA][position][1 letter MutAA]
#                    format, maintaining original order (list)
#
# File:      ~/fowler/src/utils/src_utils.py
# Type:      function

# %%
variant_index = src_utils.create_variant_index(df)

# %%
src_utils.create_heatmap_arr?
# Out:
# Signature: src_utils.create_heatmap_arr(scores, variant_index)
# Docstring:
# Create heatmap from given scores.
#
# Args:
#     scores: scores in order of variant_index (np array)
#     variant_index: order of variants in the format
#                     [1 letter WTAA][position][1 letter MutAA] (list)
# Returns:
#     heatmap_arr: 2D array where positions=rows, aas=cols
# File:      ~/fowler/src/utils/src_utils.py
# Type:      function

# %%
heatmap_arr = src_utils.create_heatmap_arr(df.loc[:, ('Radicicol', 'score')], variant_index)

# %%
heatmap_arr.shape
# Out:
# (250, 21)

# %%
src_utils.plot_heatmap?
# Out:
# Signature: src_utils.plot_heatmap(heatmap, title)
# Docstring:
# Plot heatmap.
#
# Args:
#     heatmap: 2D array where positions=rows, aas=cols
#     title: title of plot
# Returns:
#     fig: matplotlib.pyplot figure object
#     ax: matplotlib.pyplot axis object
# File:      ~/fowler/src/utils/src_utils.py
# Type:      function

# %%
fig, ax = src_utils.plot_heatmap(heatmap_arr, 'test map')

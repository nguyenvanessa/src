# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1. Check if the numbering from the DMS matches the 2src_kinDom.pdb numbering

# %%
master = pd.read_csv('../../utils/point_muts.csv', index_col=0, header=[0,1])

# %%
aa_key = {
    'His' : 'H',
    'Lys' : 'K',
    'Arg' : 'R',
    'Asp' : 'D',
    'Glu' : 'E',
    'Cys' : 'C',
    'Met' : 'M',
    'Asn' : 'N',
    'Gln' : 'Q',
    'Ser' : 'S',
    'Thr' : 'T',
    'Ala' : 'A',
    'Ile' : 'I',
    'Leu' : 'L',
    'Val' : 'V',
    'Phe' : 'F',
    'Trp' : 'W',
    'Tyr' : 'Y',
    'Gly' : 'G',
    'Pro' : 'P',
    'Ter' : '*'
    
}

for variant in master.index.tolist():
    if 'p.' not in
# Out:
# condition       Radicicol                                   Zero  \
# value                  SE        epsilon     score            SE
# _sy          5.335172e-02   0.000000e+00  0.025503  2.697229e-02
# _wt          0.000000e+00   0.000000e+00 -0.000000  0.000000e+00
# p.Ala296Arg  2.877870e-19   2.842710e-37 -1.062516  4.839518e-12
# p.Ala296Asn  3.237620e-19   3.576656e-37 -1.061823  2.866780e-01
# p.Ala296Asp  1.181331e-96  6.676056e-189 -1.133463  5.549751e-25
# ...                   ...            ...       ...           ...
# p.Val478Lys  1.999885e-21   1.747776e-41 -1.070862  9.585315e-14
# p.Val478Met  1.038719e-02   4.127776e-06 -0.483243  2.374931e-01
# p.Val478Ser  1.107723e-22   5.994830e-44 -0.597112  1.291102e-40
# p.Val478Thr  1.022153e+00   0.000000e+00  0.608660  2.736734e-01
# p.Val478Tyr  1.142321e-79  1.322177e-155 -0.694555  6.336936e-27
#
# condition
# value             epsilon     score
# _sy          0.000000e+00  0.035485
# _wt          0.000000e+00 -0.000000
# p.Ala296Arg  3.046323e-23 -1.463224
# p.Ala296Asn  6.887958e-06 -1.947827
# p.Ala296Asp  1.993584e-48 -1.577387
# ...                   ...       ...
# p.Val478Lys  1.563468e-26 -1.512068
# p.Val478Met  2.759799e-12 -0.411314
# p.Val478Ser  4.860242e-79 -0.580570
# p.Val478Thr  2.976509e-04  0.792953
# p.Val478Tyr  3.144420e-52 -0.661465
#
# [3501 rows x 6 columns]

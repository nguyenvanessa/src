# %%
from pyrosetta import *

# %%
pyrosetta.init()
# Out:
# PyRosetta-4 2020 [Rosetta PyRosetta4.MinSizeRel.python35.mac 2020.11+release.ce6f14f37b41d7372ea79cca59fad6b33adc1596 2020-03-12T19:59:10] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.MinSizeRel.python35.mac r249 2020.11+release.ce6f14f37b4 ce6f14f37b41d7372ea79cca59fad6b33adc1596 http://www.pyrosetta.org 2020-03-12T19:59:10
# core.init: command: PyRosetta -ex1 -ex2aro -database /opt/anaconda3/envs/pyrosetta/lib/python3.5/site-packages/pyrosetta-2020.11+release.ce6f14f37b4-py3.5-macosx-10.6-x86_64.egg/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-1879648155 seed_offset=0 real_seed=-1879648155
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-1879648155 RG_type=mt19937

# %%
from pyrosetta.toolbox import generate_resfile_from_pdb
generate_resfile_from_pdb("6Q21.clean.pdb", "6Q21.resfile", pack=False)
# Out:
# core.import_pose.import_pose: File '6Q21.clean.pdb' automatically determined to be of type PDB

# %%
from pyrosetta.toolbox import generate_resfile_from_pose

# %%
from pyrosetta.toolbox import pose_from_rcsb
pose = pose_from_rcsb("1YY8")
# Out:
# core.import_pose.import_pose: File '1YY8.clean.pdb' automatically determined to be of type PDB
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  CG  on residue ARG 18
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  CD  on residue ARG 18
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  NE  on residue ARG 18
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  CZ  on residue ARG 18
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  NH1 on residue ARG 18
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  NH2 on residue ARG 18
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  CG  on residue GLN:NtermProteinFull 214
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  CD  on residue GLN:NtermProteinFull 214
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OE1 on residue GLN:NtermProteinFull 214
# ...

# %%
generate_resfile_from_pose(pose, "1YY8.resfile")

# %%
from rosetta.core.pack.task import TaskFactory
task_design = TaskFactory.create_packer_task(pose)
# Out:
# /opt/anaconda3/envs/pyrosetta/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: Import of 'rosetta' as a top-level module is deprecated and may be removed in 2018, import via 'pyrosetta.rosetta'.
#   """Entry point for launching an IPython kernel.

# %%
print(task_design)
# Out:
# #Packer_Task
#
# Threads to request: ALL AVAILABLE
#
# resid	pack?	design?	allowed_aas
# 1	TRUE	FALSE	ASP:NtermProteinFull
# 2	TRUE	FALSE	ILE
# 3	TRUE	FALSE	LEU
# 4	TRUE	FALSE	LEU
# 5	TRUE	FALSE	THR
# 6	TRUE	FALSE	GLN
# 7	TRUE	FALSE	SER
# 8	TRUE	FALSE	PRO
# 9	TRUE	FALSE	VAL
# 10	TRUE	FALSE	ILE
# 11	TRUE	FALSE	LEU
# 12	TRUE	FALSE	SER
# 13	TRUE	FALSE	VAL
# 14	TRUE	FALSE	SER
# 15	TRUE	FALSE	PRO
# 16	TRUE	FALSE	GLY
# 17	TRUE	FALSE	GLU
# 18	TRUE	FALSE	ARG
# 19	TRUE	FALSE	VAL
# 20	TRUE	FALSE	SER
# 21	TRUE	FALSE	PHE
# 22	TRUE	FALSE	SER
# 23	TRUE	FALSE	CYS:disulfide
# 24	TRUE	FALSE	ARG
# 25	TRUE	FALSE	ALA
# 26	TRUE	FALSE	SER
# 27	TRUE	FALSE	GLN
# 28	TRUE	FALSE	SER
# 29	TRUE	FALSE	ILE
# 30	TRUE	FALSE	GLY
# 31	TRUE	FALSE	THR
# 32	TRUE	FALSE	ASN
# 33	TRUE	FALSE	ILE
# 34	TRUE	FALSE	HIS,HIS_D
# 35	TRUE	FALSE	TRP
# 36	TRUE	FALSE	TYR
# 37	TRUE	FALSE	GLN
# 38	TRUE	FALSE	GLN
# 39	TRUE	FALSE	ARG
# 40	TRUE	FALSE	THR
# 41	TRUE	FALSE	ASN
# 42	TRUE	FALSE	GLY
# 43	TRUE	FALSE	SER
# 44	TRUE	FALSE	PRO
# ...

# %%
from rosetta.core.pack.task import parse_resfile
parse_resfile(pose, task_design, "1YY8-K49E.resfile")

# %%
from pyrosetta.teaching import PackRotamersMover

# %%
scorefxn = get_fa_scorefxn()
# Out:
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015

# %%
pack_mover = PackRotamersMover(scorefxn, task_design)

# %%
print(scorefxn(pose))
# Out:
# -465.26760729487006

# %%
pack_mover.apply(pose)
# Out:
# core.pack.pack_rotamers: built 14735 rotamers at 868 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph

# %%
print(scorefxn(pose))
# Out:
# -1787.7100131812942

# %%
print(scorefxn(pose))
# Out:
# -1787.7100131812942
